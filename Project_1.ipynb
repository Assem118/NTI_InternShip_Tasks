# %%
#import librarires
import numpy as np
import pandas as pd

# %%
#Read CSV
df = pd.read_csv("data.csv")
# Out:
# C:\Users\alaa\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# ### Explore Data

# %%
#1- read data
#2- print head and tail
#3- info about data
#4- describe data (Numerical + Categorical)
#5- shape of data
#6- unique values and value count for each column

# %%
#first 5 rows
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3      77916    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
#last 5 rows
df.tail()
# Out:
#             Id   EmployeeName                    JobTitle       BasePay  \
# 148649  148650  Roy I Tillery                   Custodian             0
# 148650  148651   Not provided                Not provided  Not Provided
# 148651  148652   Not provided                Not provided  Not Provided
# 148652  148653   Not provided                Not provided  Not Provided
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# 148649             0             0             0      0.00              0.00
# 148650  Not Provided  Not Provided  Not Provided      0.00              0.00
# 148651  Not Provided  Not Provided  Not Provided      0.00              0.00
# 148652  Not Provided  Not Provided  Not Provided      0.00              0.00
# 148653             0       -618.13             0   -618.13           -618.13
#
#         Year  Notes         Agency Status
# ...

# %%
#information from data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
#Statistical Summary >>> Numerical
df.describe().T
# Out:
#                      count          mean           std      min        25%  \
# Id                148654.0  74327.500000  42912.857795     1.00  37164.250
# TotalPay          148654.0  74768.321972  50517.005274  -618.13  36168.995
# TotalPayBenefits  148654.0  93692.554811  62793.533483  -618.13  44065.650
# Year              148654.0   2012.522643      1.117538  2011.00   2012.000
# Notes                  0.0           NaN           NaN      NaN        NaN
#
#                        50%         75%        max
# Id                74327.50  111490.750  148654.00
# TotalPay          71426.61  105839.135  567595.43
# TotalPayBenefits  92404.09  132876.450  567595.43
# Year               2013.00    2014.000    2014.00
# Notes                  NaN         NaN        NaN

# %%
#Statistical Summary >>> Categorical
df.describe(include = "object").T
# Out:
#                  count   unique               top     freq
# EmployeeName    148654   110811         Kevin Lee       13
# JobTitle        148654     2159  Transit Operator     7036
# BasePay         148049   110165                 0      887
# OvertimePay   148654.0  66555.0               0.0  66103.0
# OtherPay      148654.0  84968.0               0.0  35218.0
# Benefits      112495.0  99635.0               0.0   1053.0
# Agency          148654        1     San Francisco   148654
# Status           38119        2                FT    22334

# %%
df.shape
# Out:
# (148654, 13)

# %%
df["Year"].unique()
# Out:
# array([2011, 2012, 2013, 2014], dtype=int64)

# %%
df.Year.unique()
# Out:
# array([2011, 2012, 2013, 2014], dtype=int64)

# %%
df["Year"].value_counts()
# Out:
# 2014    38123
# 2013    37606
# 2012    36766
# 2011    36159
# Name: Year, dtype: int64

# %%
df["JobTitle"].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
df["JobTitle"].value_counts()
# Out:
# Transit Operator                      7036
# Special Nurse                         4389
# Registered Nurse                      3736
# Public Svc Aide-Public Works          2518
# Police Officer 3                      2421
#                                       ...
# Lieutenant (Police Department)           1
# Supervising Mediator, UFCS               1
# ELECTRICAL ENGINEERING ASSOCIATE I       1
# MENTAL HEALTH HEARING OFFICER            1
# COURT AD RESOLUTION COORDINATOR          1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
df["JobTitle"].nunique()
# Out:
# 2159

# %% [markdown]
# ### Selecting and Filtering

# %%
#Select one Column
df.Year
# Out:
# 0         2011
# 1         2011
# 2         2011
# 3         2011
# 4         2011
#           ...
# 148649    2014
# 148650    2014
# 148651    2014
# 148652    2014
# 148653    2014
# Name: Year, Length: 148654, dtype: int64

# %%
#Select two Columns
df[["Year","JobTitle"]]
# Out:
#         Year                                        JobTitle
# 0       2011  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       2011                 CAPTAIN III (POLICE DEPARTMENT)
# 2       2011                 CAPTAIN III (POLICE DEPARTMENT)
# 3       2011            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4       2011    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...      ...                                             ...
# 148649  2014                                       Custodian
# 148650  2014                                    Not provided
# 148651  2014                                    Not provided
# 148652  2014                                    Not provided
# 148653  2014                      Counselor, Log Cabin Ranch
#
# [148654 rows x 2 columns]

# %%
## Employees >> year = 2011
df_2011 = df[df["Year"] == 2011]
df_2011
# Out:
#           Id        EmployeeName  \
# 0          1      NATHANIEL FORD
# 1          2        GARY JIMENEZ
# 2          3      ALBERT PARDINI
# 3          4   CHRISTOPHER CHONG
# 4          5     PATRICK GARDNER
# ...      ...                 ...
# 36154  36155       SERENA HUGHES
# 36155  36156        JOE BROWN JR
# 36156  36157      PAULETTE ADAMS
# 36157  36158       KAUKAB MOHSIN
# 36158  36159  JOSEPHINE MCCREARY
#
#                                              JobTitle    BasePay OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC      77916    56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                               ...        ...         ...
# ...

# %%
## Employees >> Jobtitle = CAPTAIN III (POLICE DEPARTMENT)
df[df["JobTitle"] == "CAPTAIN III (POLICE DEPARTMENT)"]
# Out:
#           Id       EmployeeName                         JobTitle    BasePay  \
# 1          2       GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2          3     ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 11        12   PATRICIA JACKSON  CAPTAIN III (POLICE DEPARTMENT)      99722
# 61        62         ANNA BROWN  CAPTAIN III (POLICE DEPARTMENT)  102571.24
# 65        66      RICHARD PARRY  CAPTAIN III (POLICE DEPARTMENT)  185369.69
# 91        92      DONNA MEIXNER  CAPTAIN III (POLICE DEPARTMENT)   102722.4
# 93        94        JOHN MURPHY  CAPTAIN III (POLICE DEPARTMENT)  215914.03
# 125      126    SHARON FERRIGNO  CAPTAIN III (POLICE DEPARTMENT)  185369.68
# 211      212     CROCE CASCIATO  CAPTAIN III (POLICE DEPARTMENT)  188341.62
# 214      215        JOHN FEENEY  CAPTAIN III (POLICE DEPARTMENT)  188348.55
# 225      226   STEPHEN TACCHINI  CAPTAIN III (POLICE DEPARTMENT)   188341.6
# ...

# %%
## Employees >> TotalPay > 15000
df[  (df["TotalPay"] >= 15000) & (df["Year"] == 2011)   ]["Year"]
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 30296    2011
# 30297    2011
# 30298    2011
# 30299    2011
# 30300    2011
# Name: Year, Length: 30301, dtype: int64

# %%
df[  (df["TotalPay"] >= 15000) & ((df["Year"] == 2011) | (df["Year"] == 2012))  ]

# %%
df["Year"]

# %% [markdown]
# ### Handling Errors
# #### missing values
# #### Duplicates
# #### Data types
# #### Outliers
# #### Column names

# %%
# check missing values
df.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
#Handling missing values
## 1- Drop Column
## 2- Fillna >> mean , mode, 0 , word
## 3- Dropna

# %%
##1- drop columns
df.drop("Notes", axis =1, inplace = True)

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Agency', 'Status'],
#       dtype='object')

# %%
df["Status"].value_counts()
# Out:
# FT    22334
# PT    15785
# Name: Status, dtype: int64

# %%
df["Status"].unique()
# Out:
# array([nan, 'PT', 'FT'], dtype=object)

# %%
df.drop("Status", axis = 1, inplace= True)

# %%
df.isna().sum()
# Out:
# Id                      0
# EmployeeName            0
# JobTitle                0
# BasePay               605
# OvertimePay             0
# OtherPay                0
# Benefits            36159
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# Agency                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Agency            148654 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 12.5+ MB

# %%
df.Benefits.unique()
# Out:
# array([nan, 44430.12, 69810.19, ..., '0.13', '1.24', 'Not Provided'],
#       dtype=object)

# %%
df[df['BasePay']=='Not Provided']
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Agency]
# Index: []

# %%
df = df[df['BasePay']!='Not Provided']

# %%
df.shape
# Out:
# (148650, 11)

# %%
df.isna().sum()
# Out:
# Id                    0
# EmployeeName          0
# JobTitle              0
# BasePay             605
# OvertimePay           0
# OtherPay              0
# Benefits              0
# TotalPay              0
# TotalPayBenefits      0
# Year                  0
# Agency                0
# dtype: int64

# %%
### 2 Fillna
df["Benefits"].fillna(0,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148650 entries, 0 to 148653
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148650 non-null  int64
#  1   EmployeeName      148650 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  object
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  object
#  6   Benefits          148650 non-null  object
#  7   TotalPay          148650 non-null  float64
#  8   TotalPayBenefits  148650 non-null  float64
#  9   Year              148650 non-null  int64
#  10  Agency            148650 non-null  object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 13.6+ MB

# %%
df['OvertimePay'] = df['OvertimePay'].astype(float)
# Out:
# <ipython-input-75-520542971a69>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OvertimePay'] = df['OvertimePay'].astype(float)

# %%
df[['OtherPay', 'Benefits','BasePay' ]] = df[['OtherPay', 'Benefits','BasePay' ]].astype(float, errors= 'ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148650 entries, 0 to 148653
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148650 non-null  int64
#  1   EmployeeName      148650 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  object
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          148650 non-null  float64
#  7   TotalPay          148650 non-null  float64
#  8   TotalPayBenefits  148650 non-null  float64
#  9   Year              148650 non-null  int64
#  10  Agency            148650 non-null  object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 13.6+ MB

# %%
df['OtherPay'] = df['OtherPay'].astype(float, errors= 'ignore')
# Out:
# <ipython-input-82-0b89c9e0b7b4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OtherPay'] = df['OtherPay'].astype(float, errors= 'ignore')

# %%
df['Benefits'] = df['Benefits'].astype(float, errors= 'ignore')
# Out:
# <ipython-input-84-50f23d24b666>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Benefits'] = df['Benefits'].astype(float, errors= 'ignore')

# %%
df['BasePay'] = df['BasePay'].astype(float, errors= 'ignore')

# %%
df[df['BasePay'] == ' ']
# Out:
#     Id   EmployeeName                                          JobTitle  \
# 10  11  ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#    BasePay  OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 10             71344.88   33149.9       0.0  299494.17         299494.17
#
#     Year         Agency
# 10  2011  San Francisco

# %%
df['BasePay'].unique()
# Out:
# array(['167411.18', '155966.02', '212739.13', ..., '17.26', '6.04',
#        '15.5'], dtype=object)

# %%
df= df[df['BasePay'] != ' ']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148649 entries, 0 to 148653
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148649 non-null  int64
#  1   EmployeeName      148649 non-null  object
#  2   JobTitle          148649 non-null  object
#  3   BasePay           148044 non-null  float64
#  4   OvertimePay       148649 non-null  float64
#  5   OtherPay          148649 non-null  float64
#  6   Benefits          148649 non-null  float64
#  7   TotalPay          148649 non-null  float64
#  8   TotalPayBenefits  148649 non-null  float64
#  9   Year              148649 non-null  int64
#  10  Agency            148649 non-null  object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 13.6+ MB

# %%
df.isna().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %%
df['BasePay'] = df['TotalPay']-(df['OvertimePay']+df['OtherPay']+df['Benefits'])

# %%
# check duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df['Id'].duplicated().sum()
# Out:
# 0

# %%
#Rename 
df.rename(columns = {'EmployeeName':'Name', 'Id':'Emp_id'}, inplace = True)

# %%
#Sort
df.sort_values(by = 'Emp_id', ascending = False)
# Out:
#         Emp_id               Name  \
# 148653  148654          Joe Lopez
# 148649  148650      Roy I Tillery
# 148648  148649        Leon Walker
# 148647  148648     Joann Anderson
# 148645  148646   Carolyn A Wilson
# ...        ...                ...
# 4            5    PATRICK GARDNER
# 3            4  CHRISTOPHER CHONG
# 2            3     ALBERT PARDINI
# 1            2       GARY JIMENEZ
# 0            1     NATHANIEL FORD
#
#                                               JobTitle    BasePay  \
# 148653                      Counselor, Log Cabin Ranch       0.00
# 148649                                       Custodian       0.00
# 148648                                       Custodian       0.00
# 148647                     Communications Dispatcher 2       0.00
# 148645                       Human Services Technician       0.00
# ...                                                ...        ...
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...

# %%
#Add Columns
df["Tax"] = df['TotalPay']*0.1

# %%
df.columns
# Out:
# Index(['Emp_id', 'Name', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Agency', 'Tax'],
#       dtype='object')

# %% [markdown]
# ### ASK Questions:

# %%
# 1- what is the average basepay?
# 2- what is the highest amount of overtimepay in the dataset?
# 3- what is the lowest amount of overtimepay in the dataset?
# 4- Find the jobtitle of 'NATHANIEL FORD' ?
# 5- what is the name of highest paid person (including benefits)?
# 6- what is the name of Lowest paid person (including benefits)?
# 7- what is the average BasePay of all employees per year?
# 8- How many unique job titles are there?
# 9- What are the top 5 most common jobs?

# %%
# 1- what is the average basepay?
df["BasePay"].mean()
# Out:
# 47129.769899360224

# %%
# 2- what is the highest amount of overtimepay in the dataset?
df["OvertimePay"].max()
# Out:
# 245131.88

# %%
# 3- what is the lowest amount of overtimepay in the dataset?
df["OvertimePay"].min()
# Out:
# -0.01

# %%
# 4- Find the jobtitle of 'NATHANIEL FORD' ?
df[df['Name'] == 'NATHANIEL FORD']['JobTitle']
# Out:
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# Name: JobTitle, dtype: object

# %%
# 5- what is the name of highest paid person (including benefits)?
df[ df['TotalPayBenefits'] == df['TotalPayBenefits'].max()]['Name']
# Out:
# 0    NATHANIEL FORD
# Name: Name, dtype: object

# %%
# 6- what is the name of Lowest paid person (including benefits)?
df[ df['TotalPayBenefits'] == df['TotalPayBenefits'].min()]['Name']
# Out:
# 148653    Joe Lopez
# Name: Name, dtype: object

# %%
# 7- what is the average BasePay of all employees per year?
df.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63592.322371
# 2012    38996.439890
# 2013    44680.755583
# 2014    41774.820168
# Name: BasePay, dtype: float64

# %%
df.groupby('Year')['OvertimePay'].max()
# Out:
# Year
# 2011    245131.88
# 2012    220909.48
# 2013    196689.18
# 2014    173547.73
# Name: OvertimePay, dtype: float64

# %%
# 8- How many unique job titles are there?
df['JobTitle'].nunique()
# Out:
# 2158

# %%
# 9- What are the top 5 most common jobs?
df['JobTitle'].value_counts().head(10)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Custodian                       2418
# TRANSIT OPERATOR                2388
# Firefighter                     2359
# Recreation Leader               1971
# Patient Care Assistant          1945
# Name: JobTitle, dtype: int64
